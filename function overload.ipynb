# %%
name=input("enter the name")
print("weicome",name)
# Out:
# enter the name lilly
# weicome lilly

# %%
ss="behind"
print(ss[::-2])
# Out:
# die

# %%
name="lilly"
def greet():
    print("hello" , name)
    
greet()
# Out:
# hello lilly

# %%
candy='mango bite'
def flavour():
    print(" my favourite is" ,candy)

flavour()
# Out:
#  my favourite is mango bite

# %%
def add(a,b):
    return a+b
print(add(1090,2011))
# Out:
# 3101

# %%
def add(a,b,c=0):
    return a+b+c
print(add(30,50))
print(add(30,50,20))
# Out:
# 80
# 100
