# %%
class car:
    name="BMW"
    colour="blue"

car1=car
print(car1.name)
print(car1.colour)
# Out:
# BMW
# blue

# %%
class Fruit:
    name="mango"
    colour="yellow"

fruit1=Fruit
print(fruit1.name)
print(fruit1.colour)
# Out:
# mango
# yellow

# %%
class Student:
 def __init__(self,name,age):
     self.name=name
     self.age=age
s1 =Student ("lilly",19)
print(s1.name)
print(s1.age)
# Out:
# lilly
# 19
