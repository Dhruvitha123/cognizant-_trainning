# %%
name="dhruvitha"
print(name)
# Out:
# dhruvitha

# %%
name="dhruvitha"
email="miyyapuramdhruvitha@gmail.com"
print(name)
print(email)
# Out:
# dhruvitha
# miyyapuramdhruvitha@gmail.com

# %%
city="tokyo"
print(city[2])
# Out:
# k

# %%
print(city[-1])
# Out:
# o

# %%
print(city[1:5])
# Out:
# okyo

# %%
name="dhruvitha"
print(len(name))
# Out:
# 9

# %%
name1="dhru"
name2="vitha"
print(name1+name2)
# Out:
# dhruvitha

# %%
name="lilly"
print("lilly" * 4)
# Out:
# lillylillylillylilly

# %%
print(name.upper())
# Out:
# LILLY

# %%
print(name.lower())
# Out:
# lilly

# %%
s="i like java"
print(s.replace("java","python"))
# Out:
# i like python

# %%
s="anything something"
print(s.find("something"))
# Out:
# 9

# %%
name=input("enter the name:")
print("welcome",name)k
