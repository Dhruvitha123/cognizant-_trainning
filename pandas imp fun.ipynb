# %%
import pandas as pd
s=pd.Series([10,20,34,45])
print(s.sum())
print(s.min())
print(s.max())
print(s.mean())
# Out:
# 109
# 10
# 45
# 27.25

# %%
s=pd.Series([10,20,34,45])
print(s[s>=30])
# Out:
# 2    34
# 3    45
# dtype: int64

# %%
b=pd.Series([10,20,34,45])
print([b>24])
# Out:
# [0    False
# 1    False
# 2     True
# 3     True
# dtype: bool]

# %%
import numpy as np
import pandas as pd
s=pd.Series([10,20,np.nan,39,47])
print(s)
print(s.isnull())
print(s.isnull().sum())
# Out:
# 0    10.0
# 1    20.0
# 2     NaN
# 3    39.0
# 4    47.0
# dtype: float64
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool
# 1

# %%
s=pd.Series([10,20,np.nan,39,47])
print(s.fillna(0))
# Out:
# 0    10.0
# 1    20.0
# 2     0.0
# 3    39.0
# 4    47.0
# dtype: float64

# %%
name=pd.Series(["dhruv","aksh","ash","anan","lil"])
print(name)
# Out:
# 0    dhruv
# 1     aksh
# 2      ash
# 3     anan
# 4      lil
# dtype: object

# %%
name=pd.Series(["dhruv","aksh","ash","anan","lil"])
print(name.str.upper())
print(name.str.lower())
# Out:
# 0    DHRUV
# 1     AKSH
# 2      ASH
# 3     ANAN
# 4      LIL
# dtype: object
# 0    dhruv
# 1     aksh
# 2      ash
# 3     anan
# 4      lil
# dtype: object

# %%
n=pd.Series([23,34,56,32])
print(s.sort_values())
# Out:
# 0    10.0
# 1    20.0
# 3    39.0
# 4    47.0
# 2     NaN
# dtype: float64

# %%
n=pd.Series([23,34,56,32])
print(s.sort_values(ascending=False))
# Out:
# 4    47.0
# 3    39.0
# 1    20.0
# 0    10.0
# 2     NaN
# dtype: float64

# %%
n=pd.Series([23,45,67,41,12])
print(n.unique())
# Out:
# [23 45 67 41 12]

# %%
s=pd.eries([34,45,23,12,13])
print(s.value_counts())
# Out:
# 34    1
# 45    1
# 23    1
# 12    1
# 13    1
# Name: count, dtype: int64

# %%
s=pd.Series([34,45,23,12,13])
print(s.tolist())
# Out:
# [34, 45, 23, 12, 13]

# %%
s=pd.Series([34,45,23,np.nan,13])
print(s.dropna())
# Out:
# 0    34.0
# 1    45.0
# 2    23.0
# 4    13.0
# dtype: float64

# %%
import pandas as pd
b=pd.Series([12,14,15,16,22,34,67,78])
print([b>40])
print(b[b>40]&b[b<57])
# Out:
# [0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7     True
# dtype: bool]
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# dtype: bool
# C:\Users\miyya\AppData\Local\Temp\ipykernel_2492\876674569.py:4: FutureWarning: Operation between Series with different indexes that are not of numpy boolean or object dtype will no longer return a numpy boolean result in a future version. Cast both Series to object type to maintain the prior behavior.
#   print(b[b>40]&b[b<57])
