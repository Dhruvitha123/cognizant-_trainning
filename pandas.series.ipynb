# %%
import pandas as pd
marks =pd.Series([12,3,45,23,30])
mark =pd.Series()
print(marks)
print(mark)
# Out:
# 0    12
# 1     3
# 2    45
# 3    23
# 4    30
# dtype: int64
# Series([], dtype: object)

# %%
marks=pd.Series([12,40,35,16,4])
print(marks[3])
# Out:
# 16

# %%
student_name=pd.Series(["DhruV","aksh","ash","anan"])
print(student_name)
# Out:
# 0    DhruV
# 1     aksh
# 2      ash
# 3     anan
# dtype: object

# %%
employe_salary=pd.Series([10000,35000,50000,20000])
print(employe_salary)
# Out:
# 0    10000
# 1    35000
# 2    50000
# 3    20000
# dtype: int64

# %%
marks=pd.Series((23,45,34,12,68))
students=pd.Series(("tom","himansh","tim","uma"))
print(marks)
print (students)
# Out:
# 0    23
# 1    45
# 2    34
# 3    12
# 4    68
# dtype: int64
# 0        tom
# 1    himansh
# 2        tim
# 3        uma
# dtype: object

# %%
student={"hyma":50,
          "dhruv":19
         }
s=pd.Series(student)
print(s)
# Out:
# hyma     50
# dhruv    19
# dtype: int64

# %%
d=pd.Series([120,345,456,234])
print(d)
# Out:
# 0    120
# 1    345
# 2    456
# 3    234
# dtype: int64

# %%
ci=pd.Series([190,342,122,145],
             index=["a","b","e","h"])
print(ci)
print(ci["e"])
print(ci.index)
print(ci.values)
print(ci.dtype)
print(ci.size)
# Out:
# a    190
# b    342
# e    122
# h    145
# dtype: int64
# 122
# Index(['a', 'b', 'e', 'h'], dtype='object')
# [190 342 122 145]
# int64
# 4
