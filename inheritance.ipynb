# %%
class parent:
    def fun1(self):
     print("this function is belongs to parent class")

class Child(parent):
    def fun2(self):
     print("this function is belongs to child class")
object = Child()
object.fun1()
object.fun2()
# Out:
# this function is belongs to parent class
# this function is belongs to child class

# %%
class parent:
    def fun1(self):
     print("this function is belongs to parent calss")

class child(parent):
    def fun1(self):
     print("this function is belongs to child class")
object = child()
object.fun1()
# Out:
# this function is belongs to child class

# %%
class First:
    def fun1(self):
     print("this function is belongs to first calss")

class Second(First):
    def fun1(self):
     print("this function is belongs to second class")
object = Second()
object.fun1()
# Out:
# this function is belongs to second class
