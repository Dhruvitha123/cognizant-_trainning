# %%
import pandas as pd
data={
    "date":["2026-08-5","2001-10-20","2006-08-13","1980-07-30"]
}
result=pd.DataFrame(data)
print(result)
# Out:
#          date
# 0   2026-08-5
# 1  2001-10-20
# 2  2006-08-13
# 3  1980-07-30

# %%
result["date"]=pd.to_datetime(result["date"])
print(result)
# Out:
#         date
# 0 2026-08-05
# 1 2001-10-20
# 2 2006-08-13
# 3 1980-07-30

# %%
result["date"].dt.year
# Out:
# 0    2026
# 1    2001
# 2    2006
# 3    1980
# Name: date, dtype: int32

# %%
result["date"].dt.month
# Out:
# 0     8
# 1    10
# 2     8
# 3     7
# Name: date, dtype: int32

# %%
result["date"].dt.day
# Out:
# 0     5
# 1    20
# 2    13
# 3    30
# Name: date, dtype: int32

# %%
result["date"].dt.day_name()
# Out:
# 0    Wednesday
# 1     Saturday
# 2       Sunday
# 3    Wednesday
# Name: date, dtype: object

# %%
pd.Timestamp.now()
# Out:
# Timestamp('2026-06-18 16:24:46.924204')

# %%
import pandas as pd
from datetime import datetime
date1=datetime(2001,10,20)
date2=datetime(2006,8,13)
print(date2-date1)
# Out:
# 1758 days, 0:00:00
