# %%
name=["lilly","ashmitha","akshaya","ananya"]
it=iter(name)
print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# lilly
# ashmitha
# akshaya
# ananya

# %%
num=["1","2","3","4"]
it=iter(num)
print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# 1
# 2
# 3
# 4

# %%
food=["oats","rice","biryani","burger"]
it=iter(num)
print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# 1
# 2
# 3
# 4

# %%
def numbers():
    yield 1
    yield 2
    yield 3
gen = numbers()
print(next(gen))
print(next(gen))
print(next(gen))
# Out:
# 1
# 2
# 3
