# %%
def add (*numbers):
    print(sum(numbers))
add(10,20)
add(10,20,30)
add(10,20,30,40)
add(10,20,30,40,50)
# Out:
# 30
# 60
# 100
# 150

# %%
def student (*marks):
    print(sum(marks))
student(20,50)
student(30,40,50)
student(1,30,50)
# Out:
# 70
# 120
# 81
